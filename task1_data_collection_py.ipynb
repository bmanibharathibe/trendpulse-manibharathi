# %% [markdown]
# <a href="https://colab.research.google.com/github/bmanibharathibe/trendpulse-manibharathi/blob/main/task1_data_collection_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# GitHub trending repositories API
url = "https://api.github.com/search/repositories?q=stars:>10000&sort=stars"

response = requests.get(url)
data = response.json()

repos = []

for repo in data['items']:
    repos.append({
        "name": repo["name"],
        "owner": repo["owner"]["login"],
        "stars": repo["stargazers_count"],
        "forks": repo["forks_count"],
        "language": repo["language"]
    })

df = pd.DataFrame(repos)

# Save raw data
df.to_csv("trending_repos_raw.csv", index=False)

print("Data collection completed")
print(df.head())
# Out:
# Data collection completed
#                      name            owner   stars  forks    language
# 0        build-your-own-x  codecrafters-io  487425  45863    Markdown
# 1                 awesome     sindresorhus  453176  34041        None
# 2            freeCodeCamp     freeCodeCamp  442212  44183  TypeScript
# 3             public-apis      public-apis  420193  45721      Python
# 4  free-programming-books  EbookFoundation  385191  66092      Python
